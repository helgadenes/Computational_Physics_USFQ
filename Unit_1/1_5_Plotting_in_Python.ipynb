# %% [markdown]
# <a href="https://colab.research.google.com/github/helgadenes/Computational_Physics_USFQ/blob/main/Unit_1/1_5_Plotting_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Plotting in Python
#
# We will use mainly Matplotlib for plotting: https://matplotlib.org/
#
# Some examples on how to use Matplotlib for plotting can be found here:
#
# https://matplotlib.org/tutorials/introductory/sample_plots.html
#
# https://matplotlib.org/gallery/index.html
#
# Other examples can be found on forums, e.g. StackOverflow:
#
# https://stackoverflow.com/
#
# Asking questions on Google is also very helpful as there are many links, examples, solutions to problems, etc.
#
# Python is a community-developed language, so you are also welcome to report bugs:
#
# https://bugs.python.org/
#
#
# ## Matplotlib
#
# It is a library used for visualization with Python.
# It allows users to create static, animated, and interactive plots.
#
# "It makes easy things easy and hard things possible." (from Matplotlib website)
# Customising plots is easy. The documentation is comprehensive and easy to find.
#
# ### pyplot():
# Basic plotting with pyplot
#
# Pyplot is an interface to plot using Matlab- and Mathematica-like plotting sequences.
#
# It facilitates plotting.
# Plotting can be done without using "objects"
#
# *(Based on lecture notes by Wladmir Banda-Barragán)*

# %% [markdown]
# ## 1. Inline plotting:

# %%
# Import third-party libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# This line is added for inline, interactive plotting
# %matplotlib inline

# Generate a couple of vectors
x = np.arange(0, 6*np.pi, 0.01)

y = np.sin(x)

# Plotting
plt.plot(x,y)

# %% [markdown]
# ## 2. Figure environments:
#
# - This refers to code lines that open, plot and show the figure.

# %%
# The basic syntax for a fig. env.

# Open env.
plt.figure()

# Plot
plt.plot(x,y)

# Show/Save
plt.show()
# plt.savefig()

# In actual code, we should always clean up the memory
# plt.close()

# %%
# Customise our figures:

# Open env.
plt.figure(figsize=(4,3))

# Plot
plt.plot(x, y, color = "red", linestyle = ":")

# Title with latex syntax
plt.title(r"$\sin(x)$")

# Axes titles
plt.xlabel(r"$x$")
plt.ylabel(r"$y=\sin(x)$")

# Show/Save
plt.show()

# %% [markdown]
# ## This is only for Google Colab.
#
# In Google Colab, we need to mount the Google Drive folder where we want to save anything.

# %%
# Import Google Drive capabilities
from google.colab import drive

# Mount the Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive
# Out:
# MyDrive  Shareddrives

# %%
# !ls /content/drive/MyDrive/'Colab Notebooks'
# Out:
# 106-Plotting-in-Python.ipynb	  112-Interpolation.ipynb
# 107-Python-Functions.ipynb	  113-extrapolation.ipynb
# 108-Data-Input-Output.ipynb	  1.3_Python-Basics-Review.ipynb.ipynb
# 109-Data-IO-Pandas.ipynb	  1_4-Numpy-Arrays.ipynb
# 110-DataFitting-Regression.ipynb  CP_1.3_Editors-IDEs-Coding.ipynb
# 111-Chi-Sqr-Fitting.ipynb

# %%
# Customise our figures:

# Open env.
plt.figure(figsize=(4,3))

# Plot
plt.plot(x, y, color = "red", linestyle = ":")

# Title with latex syntax
plt.title(r"$\sin(x)$")

# Axes titles
plt.xlabel(r"$x$")
plt.ylabel(r"$y=\sin(x)$")

# Show/Save
plt.savefig("./sine_plot.png")

# %%
# Customise our figures:

# Open env.
plt.figure(figsize=(4,3))

# Plot
plt.plot(x, y, color = "red", linestyle = ":")

# Title with latex syntax
plt.title(r"$\sin(x)$")

# Axes titles
plt.xlabel(r"$x$")
plt.ylabel(r"$y=\sin(x)$")

# Show/Save
#plt.show()
plt.savefig("/content/drive/MyDrive/Colab Notebooks/sine.png")

# %%
# !ls
# Out:
# drive  sample_data  sine_plot.eps  sine_plot.png

# %%
# !ls /content/drive/MyDrive/Colab\ Notebooks
# Out:
# 106-Plotting-in-Python.ipynb	  113-extrapolation.ipynb
# 107-Python-Functions.ipynb	  1.3_Python-Basics-Review.ipynb.ipynb
# 108-Data-Input-Output.ipynb	  1_4-Numpy-Arrays.ipynb
# 109-Data-IO-Pandas.ipynb	  CP_1.3_Editors-IDEs-Coding.ipynb
# 110-DataFitting-Regression.ipynb  sine.eps
# 111-Chi-Sqr-Fitting.ipynb	  sine.png
# 112-Interpolation.ipynb

# %% [markdown]
# ## Example: overplotting

# %%
# Superimpose plots:

w = np.cos(x)

# Open env.
plt.figure(figsize=(4,3))

# Plot
plt.plot(x, y, color = "red", linestyle = ":", label = r"$\sin(x)$")
plt.plot(x, w, color = "green", linestyle = "-.", label = r"$\cos(x)$")

# Title with latex syntax
plt.title(r"$\sin(x)$ and $\cos(x)$")

# Axes titles
plt.xlabel(r"$x$")
plt.ylabel(r"$y,w$")

# Legend is added with loc for location
plt.legend(loc=2) # loc -> LOCATION

# Show/Save
plt.show()

# %% [markdown]
# ## Example: subplots (multi-panel figures)

# %%
# Method 1: Multi-panel figure

plt.figure()

plt.subplot(2, 2, 1) # we are defining the subplots here
plt.plot(x, x, color = "red", label = "linear")
plt.legend()
plt.xlim(0,20)
plt.ylim(0,20)

plt.subplot(2, 2, 2)
plt.plot(x, x**2, color = "magenta", label = "parabolic")
plt.legend()
plt.xlim(0,20)
plt.ylim(0,20)

plt.subplot(2, 2, 3)
plt.plot(x, x**3, color = "blue", label = "3rd order")
plt.legend()
plt.xlim(0,20)
plt.ylim(0,20)

plt.subplot(2, 2, 4)
plt.plot(x, x**4, color = "green", label = "4th order")
plt.legend()
plt.xlim(0,20)
plt.ylim(0,20)

plt.show()
# plt.savefig("/content/drive/MyDrive/Colab Notebooks/multipanel.eps")

# %%
# Method 2: Multi-panel figure using axes objects

fig, ax = plt.subplots(2, 2)

# note how the subplots are defined in a different way

ax[0, 0].plot(x, x, color = "red", label = "linear")
ax[1, 0].plot(x, x**2, color = "magenta", label = "linear")
ax[0, 1].plot(x, x**3, color = "blue", label = "linear")
ax[1, 1].plot(x, x**4, color = "green", label = "linear")

plt.show()

# %%
# Method 2: Multi-panel figure using axes objects

fig, ax = plt.subplots(nrows = 2, ncols = 2)
ax1, ax2, ax3, ax4 = ax.flatten()

ax1.plot(x, x, color = "red", label = "linear")
ax2.plot(x, x**2, color = "magenta", label = "linear")
ax3.plot(x, x**3, color = "blue", label = "linear")
ax4.plot(x, x**4, color = "green", label = "linear")

plt.show()

# %% [markdown]
# ## Example: Scatter plots (markers)

# %%
# Let us generate randon numbers

# Set up a seed
np.random.seed(123)

# Generates randon numbers
new_x = np.random.randn(50)
new_y = np.random.randn(50)

print(new_x[-1])
#print(new_x.shape, new_y.shape)
# Out:
# 2.2381433384979528

# %%
# Open env.
plt.figure(figsize=(4,3))

# Plot
plt.plot(new_x, new_y, label = r"$rand(x)$")

# Title with latex syntax
plt.title("Random numbers")

# Axes titles
plt.xlabel(r"$rand(x)$")
plt.ylabel(r"$rand(y)$")

# Legend is added with loc for location
plt.legend(loc=3)

# Show/Save
plt.show()

# %%
# Open env.
plt.figure(figsize=(4,3))

# Plot
plt.scatter(new_x, new_y)

# Title with latex syntax
plt.title("Random numbers")

# Axes titles
plt.xlabel(r"$rand(x)$")
plt.ylabel(r"$rand(y)$")

# Legend is added with loc for location
plt.legend(loc=3)

# Show/Save
plt.show()
# Out:
# /tmp/ipython-input-64773487.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc=3)

# %% [markdown]
# ### Example: histograms

# %%
# Let's make histograms of new_x and new_y

new_x = np.random.randn(500)
new_y = np.random.randn(500)

#https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html

count, bins, _ = plt.hist(new_x, bins = 20, alpha = 0.6)
count, bins, _ = plt.hist(new_y, bins = 20, alpha = 0.3)

# %%
count, bins, _ = plt.hist(new_x, bins = 20, alpha = 1., histtype = "step")
count, bins, _ = plt.hist(new_y, bins = 20, alpha = 1., histtype = "step")

# %%
# Print the objects that plt.hist() returned

print(count.shape)
print(bins.shape)
# Out:
# (20,)
# (21,)

# %%
# Uniform Distribution

new_z = np.random.uniform(-3,3,500)

#https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html

# we can save the counts and the bins in variables and use them for other plots or calculations
count, bins, unimportant = plt.hist(new_z, bins = 20, alpha = 0.3)

count, bins, unimportant = plt.hist(new_x, bins = 20, alpha = 0.7)

# %%
# Uniform Distribution
# We can change the type of the histogram with: histtype

new_z = np.random.uniform(-3,3,500)

#https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html

count1, bins1, unimportant1 = plt.hist(new_z, bins = 20, alpha = 0.3, histtype = "step")

count2, bins2, unimportant2 = plt.hist(new_x, bins = 20, alpha = 0.7, histtype = "step")

# %%
print(count1.shape, bins1.shape)

print(type(count1))
# Out:
# (20,) (21,)
# <class 'numpy.ndarray'>

# %%
plt.figure(figsize=(4,3))

plt.plot(bins1[1:], count1, linestyle="-", marker = "+", label="uniform")
plt.plot(bins2[1:], count2, linestyle="-", marker = "d", label="normal")

plt.legend()
plt.show()

# %% [markdown]
# ### Getting the midpoints for the bins

# %%
print(bins1)
# Out:
# [-2.99959297 -2.70119456 -2.40279615 -2.10439773 -1.80599932 -1.50760091
#  -1.2092025  -0.91080409 -0.61240568 -0.31400726 -0.01560885  0.28278956
#   0.58118797  0.87958638  1.1779848   1.47638321  1.77478162  2.07318003
#   2.37157844  2.66997686  2.96837527]

# %%
print(bins1.shape)
print(bins1[1:].shape)
print(bins1[:-1].shape)
# Out:
# (21,)
# (20,)
# (20,)

# %%
# Shifting the arrays to get the middle values
mid_bins = (bins1[1:] + bins1[:-1])/2

print(mid_bins)
print(mid_bins.shape)
# Out:
# [-2.85039376 -2.55199535 -2.25359694 -1.95519853 -1.65680012 -1.3584017
#  -1.06000329 -0.76160488 -0.46320647 -0.16480806  0.13359035  0.43198877
#   0.73038718  1.02878559  1.327184    1.62558241  1.92398083  2.22237924
#   2.52077765  2.81917606]
# (20,)

# %%
#section = np.arange(-3, 3, 1/20.)
#plt.fill_between(section,f(section))

plt.figure(figsize=(4,3))

plt.plot(mid_bins, count1, linestyle="-", marker = "+", label="uniform")
plt.plot(mid_bins, count2, linestyle="-", marker = "d", label="normal")

plt.legend()
plt.show()
